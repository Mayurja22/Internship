# %%
import selenium 
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By 
import time 
import urllib.request

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
product_to_search = input("Search for any SmartPhone: ")
# Out:
# Search for any SmartPhone: IQOO

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input")
search.send_keys(product_to_search)
search.click()

# %%
btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div/div/div[1]/div[1]/header/div[1]/div[2]/form/div/button")
btn.click()

# %%
    smartphones = []
    
    product_containers = driver.find_elements(By.XPATH, "//div[@class='tUxRFH']") 
    
    for i in range(len(product_containers)):
        try:
        
        
            product_containers = driver.find_elements(By.XPATH, "//div[@class='tUxRFH']")  
            container = product_containers[i]
            brand_name = container.find_element(By.XPATH, ".//div[@class='KzDlHZ']").text.split()[0]  # Brand name from product title
            product_name = container.find_element(By.XPATH, ".//div[@class='KzDlHZ']").text  # Full product title
            product_url = container.find_element(By.XPATH, ".//a[@class='CGtC98']").get_attribute("href")  # Product URL
            price = container.find_element(By.XPATH, ".//div[@class='Nx9bqj _4b5DiR']").text  # Price
            ram=container.find_element(By.XPATH,"//div[@class='_6NESgJ']/ul/li[1]").text.split(' | ')[0].strip()
            
            driver.get(product_url)
            time.sleep(2)  
            
            btn=driver.find_element(By.XPATH,"//button[@class='QqFHMw _4FgsLt']")
            btn.click()
            
            
            try:
                color = driver.find_element(By.XPATH, "//div[@class='_1OjC5I']/div[1]/table/tbody/tr[4]/td[2]/ul/li").text
            except:
                color = "-"
                
            
            
            try:
                rom = driver.find_element(By.XPATH, "//div[@class='_1OjC5I']/div[4]/table/tbody/tr[1]/td[2]/ul/li").text
            except:
                rom = "-"
                
            try:
                primary_camera = driver.find_element(By.XPATH, "//div[@class='U+9u4y']/div[2]/ul/li[3]").text.split('|')[0].strip()
            except:
                primary_camera = "-"
                
            try:
                secondary_camera = driver.find_element(By.XPATH, "//div[@class='U+9u4y']/div[2]/ul/li[3]").text.split('|')[1].strip()
            except:
                secondary_camera = "-"
                
            try:
                display_size = driver.find_element(By.XPATH, "//div[@class='U+9u4y']/div[2]/ul/li[2]").text
            except:
                display_size = "-"
                
            try:
                battery_capacity = driver.find_element(By.XPATH, "//div[@class='U+9u4y']/div[2]/ul/li[4]").text
            except:
                battery_capacity = "-"
         
            
            smartphones.append({
                "Brand Name": brand_name,
                "Smartphone name": product_name,
                "Colour": color,
                "RAM": ram,
                "Storage(ROM)": rom,
                "Primary Camera": primary_camera,
                "Secondary Camera": secondary_camera,
                "Display Size": display_size,
                "Battery Capacity": battery_capacity,
                "Price": price,
                "Product URL": product_url
            })
            driver.back()
            time.sleep(2)
        except Exception as e:
            print(f"Error scraping product: {e}")

# %%
df = pd.DataFrame(smartphones)

# %%
df
# Out:
#    Brand Name                                    Smartphone name  \
# 0        IQOO                      IQOO Z9x (Storm Grey, 128 GB)
# 1        IQOO                   IQOO Z9x (Tornado Green, 128 GB)
# 2        IQOO            IQOO Z7 Pro 5G (Graphite Matte, 256 GB)
# 3        IQOO                   IQOO z9x (Tornado Green, 128 GB)
# 4        IQOO                   IQOO Z9X (Tornado Green, 128 GB)
# 5        IQOO                IQOO Z9 Lite 5G (Aqua Flow, 128 GB)
# 6        IQOO              IQOO Z9 Lite 5G (Mocha Brown, 128 GB)
# 7        IQOO              IQOO Z9 Lite 5G (Mocha Brown, 128 GB)
# 8        IQOO               IQOO Z9 Lite 5G (?Aqua Flow, 128 GB)
# 9        IQOO                 IQOO Z9 5G (Graphene Blue, 256 GB)
# 10       IQOO                    IQOO Z9 (Brushed Green, 128 GB)
# 11       IQOO                 IQOO Z9 5G (Brushed Green, 256 GB)
# 12       IQOO        IQOO Z9S PRO 5G (Flamboyant Orange, 256 GB)
# ...
