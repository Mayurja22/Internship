# %%
import selenium 
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By 
import time 
import urllib.request
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://images.google.com/")

# %%
keywords = ['fruits', 'cars', 'Machine Learning', 'Guitar', 'Cakes']

# Loop through each keyword
for keyword in keywords:
    # Go to Google Images
    driver.get("https://images.google.com/")
    time.sleep(2)  # Wait for the page to load

    # Search for the keyword
    search_box = driver.find_element(By.NAME, "q")
    search_box.clear()
    search_box.send_keys(keyword)
    search_box.send_keys(Keys.RETURN)
    time.sleep(2)  # Wait for results to load

    # Scroll down to load more images
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for images to load

    # Find image elements
    images = driver.find_elements(By.XPATH, "//img[@class='rg_i Q4LuWd']")

    # Download images
    img_count = 0
    for img in images:
        if img_count >= 10:
            break
        try:
            src = img.get_attribute('src')
            if src:
                print(f"Downloading {src}")
                urllib.request.urlretrieve(src, f"C:/Users/Mayur/Desktop/IMAGES/{keyword}_{img_count}.png")
                img_count += 1
        except Exception as e:
            print(f"Could not download image {img_count}: {e}")
            
driver.quit()

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
driver.get("https://images.google.com/")

# %%
product_to_search = input("Enter the product to search: ")
# Out:
# Enter the product to search: Cars

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search.send_keys(product_to_search)
search.click()

# %%
btn=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button")
btn.click()

# %%
cars = []
i = 10
img_car = driver.find_elements(By.XPATH, "//div[@class='H8Rx8c']/g-img/img")
for i, x in enumerate(img_car[:10]):
    src = x.get_attribute('src')
    print(src)
    fruits.append(src)
    # Use forward slashes for the file path
    urllib.request.urlretrieve(src, f"C:/Users/Mayur/Desktop/IMAGES/captcha{i}.png")
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
product_to_search = input("Enter the product to search: ")
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/form/div[1]/div[1]/div[2]/div/div[2]/textarea")
search.send_keys(product_to_search)
search.click()
# Out:
# Enter the product to search: Machine Learning

# %%
driver.quit()
